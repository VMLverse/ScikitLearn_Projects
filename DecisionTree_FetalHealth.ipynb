# %% [markdown]
# #Verify Environment

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# %% [markdown]
# # Common Imports

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
plt.style.use('seaborn')

# %%
import seaborn as sns
sns.set()

# %%
pd.set_option('display.max_rows', 100) 
pd.set_option('display.max_colwidth', 199)

# %% [markdown]
# #Check Data

# %%
health_data = pd.read_csv("./fetal_health.csv")

# %%
health_data.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                                    43.0  ...           62.0
# 1                                                     0.0  ...           68.0
# 2                                                     0.0  ...           68.0
# 3                                                     0.0  ...           53.0
# 4                                                     0.0  ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           2.0
# 1                 0.0           1.0
# 2                 0.0           1.0
# 3                 1.0           1.0
# 4                 1.0           1.0
#
# [5 rows x 22 columns]

# %%
#print list of columns
health_data.columns
# Out:
# Index(['baseline value', 'accelerations', 'fetal_movement',
#        'uterine_contractions', 'light_decelerations', 'severe_decelerations',
#        'prolongued_decelerations', 'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
#        'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
#        'histogram_median', 'histogram_variance', 'histogram_tendency',
#        'fetal_health'],
#       dtype='object')

# %% [markdown]
# On This Dataset Cardiotocograms (CTGs) are a simple and cost accessible option to assess fetal health, allowing healthcare professionals to take action in order to prevent child and maternal mortality. The equipment itself works by sending ultrasound pulses and reading its response, thus shedding light on fetal heart rate (FHR), fetal movements, uterine contractions and more.
#
# This dataset contains 2126 records of features extracted from Cardiotocogram exams, which were then classified by expert obstetrician into 3 classes:
#
# Normal
# Suspect
# Pathological
#
#
# Target
#
# 'fetal_health' Tagged as 1 (Normal), 2 (Suspect) and 3 (Pathological)

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
#  8   mean_value_of_short_term_variability                    2126 non-null   float64
#  9   percentage_of_time_with_abnormal_long_term_variability  2126 non-null   float64
#  10  mean_value_of_long_term_variability                     2126 non-null   float64
#  11  histogram_width                                         2126 non-null   float64
#  12  histogram_min                                           2126 non-null   float64
#  13  histogram_max                                           2126 non-null   float64
#  14  histogram_number_of_peaks                               2126 non-null   float64
#  15  histogram_number_of_zeroes                              2126 non-null   float64
#  16  histogram_mode                                          2126 non-null   float64
#  17  histogram_mean                                          2126 non-null   float64
#  18  histogram_median                                        2126 non-null   float64
#  19  histogram_variance                                      2126 non-null   float64
#  20  histogram_tendency                                      2126 non-null   float64
#  21  fetal_health                                            2126 non-null   float64
# dtypes: float64(22)
# memory usage: 365.5 KB

# %%
health_data.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# std               0.002960              0.000057                  0.000590
# min               0.000000              0.000000                  0.000000
# 25%               0.000000              0.000000                  0.000000
# 50%               0.000000              0.000000                  0.000000
# 75%               0.003000              0.000000                  0.000000
# max               0.015000              0.001000                  0.005000
#
#        abnormal_short_term_variability  mean_value_of_short_term_variability  \
# count                      2126.000000                           2126.000000
# mean                         46.990122                              1.332785
# std                          17.192814                              0.883241
# min                          12.000000                              0.200000
# 25%                          32.000000                              0.700000
# 50%                          49.000000                              1.200000
# 75%                          61.000000                              1.700000
# max                          87.000000                              7.000000
#
#        percentage_of_time_with_abnormal_long_term_variability  ...  \
# count                                              2126.00000  ...
# mean                                                  9.84666  ...
# std                                                  18.39688  ...
# min                                                   0.00000  ...
# 25%                                                   0.00000  ...
# 50%                                                   0.00000  ...
# 75%                                                  11.00000  ...
# max                                                  91.00000  ...
#
#        histogram_min  histogram_max  histogram_number_of_peaks  \
# count    2126.000000    2126.000000                2126.000000
# mean       93.579492     164.025400                   4.068203
# std        29.560212      17.944183                   2.949386
# min        50.000000     122.000000                   0.000000
# 25%        67.000000     152.000000                   2.000000
# 50%        93.000000     162.000000                   3.000000
# 75%       120.000000     174.000000                   6.000000
# max       159.000000     238.000000                  18.000000
#
#        histogram_number_of_zeroes  histogram_mode  histogram_mean  \
# count                 2126.000000     2126.000000     2126.000000
# mean                     0.323612      137.452023      134.610536
# std                      0.706059       16.381289       15.593596
# min                      0.000000       60.000000       73.000000
# 25%                      0.000000      129.000000      125.000000
# 50%                      0.000000      139.000000      136.000000
# 75%                      0.000000      148.000000      145.000000
# max                     10.000000      187.000000      182.000000
#
#        histogram_median  histogram_variance  histogram_tendency  fetal_health
# count       2126.000000         2126.000000         2126.000000   2126.000000
# mean         138.090310           18.808090            0.320320      1.304327
# std           14.466589           28.977636            0.610829      0.614377
# min           77.000000            0.000000           -1.000000      1.000000
# 25%          129.000000            2.000000            0.000000      1.000000
# 50%          139.000000            7.000000            0.000000      1.000000
# 75%          148.000000           24.000000            1.000000      1.000000
# max          186.000000          269.000000            1.000000      3.000000
#
# [8 rows x 22 columns]

# %%
health_data.shape
# Out:
# (2126, 22)

# %%
# Count the missing and null values for dataset fetal healt.
miss_values = health_data.columns[health_data.isnull().any()]
print(f"Missing values:\n{health_data[miss_values].isnull().sum()}")

null_values = health_data.columns[health_data.isna().any()]
print(f"Null values:\n{health_data[null_values].isna().sum()}")
# Out:
# Missing values:
# Series([], dtype: float64)
# Null values:
# Series([], dtype: float64)

# %%
#1 Normal
#2 Suspect
#3 Pathological
health_data["fetal_health"].value_counts()
# 1.0    1655
# 2.0     295
# 3.0     176
# Out:
# 1.0    1655
# 2.0     295
# 3.0     176
# Name: fetal_health, dtype: int64

# %%
(health_data["fetal_health"].value_counts()/health_data["fetal_health"].shape)*100
# Out:
# 1.0    77.845720
# 2.0    13.875823
# 3.0     8.278457
# Name: fetal_health, dtype: float64

# %%
health_data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#Find total number of zeros
# Count number of zeros in all columns of Dataframe
for column_name in health_data.columns:
    column = health_data[column_name]
    # Get the count of Zeros in column 
    count = (column == 0).sum()
    print('Count of zeros in column', column_name, ' is : ', count)
# Out:
# Count of zeros in column baseline value  is :  0
# Count of zeros in column accelerations  is :  894
# Count of zeros in column fetal_movement  is :  1311
# Count of zeros in column uterine_contractions  is :  332
# Count of zeros in column light_decelerations  is :  1231
# Count of zeros in column severe_decelerations  is :  2119
# Count of zeros in column prolongued_decelerations  is :  1948
# Count of zeros in column abnormal_short_term_variability  is :  0
# Count of zeros in column mean_value_of_short_term_variability  is :  0
# Count of zeros in column percentage_of_time_with_abnormal_long_term_variability  is :  1240
# Count of zeros in column mean_value_of_long_term_variability  is :  137
# Count of zeros in column histogram_width  is :  0
# Count of zeros in column histogram_min  is :  0
# Count of zeros in column histogram_max  is :  0
# Count of zeros in column histogram_number_of_peaks  is :  107
# Count of zeros in column histogram_number_of_zeroes  is :  1624
# Count of zeros in column histogram_mode  is :  0
# Count of zeros in column histogram_mean  is :  0
# Count of zeros in column histogram_median  is :  0
# Count of zeros in column histogram_variance  is :  187
# Count of zeros in column histogram_tendency  is :  1115
# Count of zeros in column fetal_health  is :  0

# %%
corr_matrix = health_data.corr()
corr_matrix["fetal_health"].sort_values(ascending=False)
# Out:
# fetal_health                                              1.000000
# prolongued_decelerations                                  0.484859
# abnormal_short_term_variability                           0.471191
# percentage_of_time_with_abnormal_long_term_variability    0.426146
# histogram_variance                                        0.206630
# baseline value                                            0.148151
# severe_decelerations                                      0.131934
# fetal_movement                                            0.088010
# histogram_min                                             0.063175
# light_decelerations                                       0.058870
# histogram_number_of_zeroes                               -0.016682
# histogram_number_of_peaks                                -0.023666
# histogram_max                                            -0.045265
# histogram_width                                          -0.068789
# mean_value_of_short_term_variability                     -0.103382
# histogram_tendency                                       -0.131976
# uterine_contractions                                     -0.204894
# histogram_median                                         -0.205033
# mean_value_of_long_term_variability                      -0.226797
# histogram_mean                                           -0.226985
# histogram_mode                                           -0.250412
# accelerations                                            -0.364066
# Name: fetal_health, dtype: float64

# %% [markdown]
# #Stratified data split

# %%
#TEMPLATE - prepare X & y
X = health_data.drop("fetal_health",axis = 1)
y = health_data.fetal_health

# %%
#TEMPLATE - create a stratified split
from sklearn.model_selection import train_test_split
X_train_raw,X_test_raw,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42, stratify=y)
#total rows: 2126
#train set: 1488
  #train set: 
  #validation set: 
#test set: 638

# %%
X.shape
# Out:
# (2126, 21)

# %%
feature_names = list(health_data.columns[:-1])
feature_target = list(health_data.columns[-1:])
print('feature_names:',feature_names)
print('feature_target:',feature_target)
# Out:
# feature_names: ['baseline value', 'accelerations', 'fetal_movement', 'uterine_contractions', 'light_decelerations', 'severe_decelerations', 'prolongued_decelerations', 'abnormal_short_term_variability', 'mean_value_of_short_term_variability', 'percentage_of_time_with_abnormal_long_term_variability', 'mean_value_of_long_term_variability', 'histogram_width', 'histogram_min', 'histogram_max', 'histogram_number_of_peaks', 'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean', 'histogram_median', 'histogram_variance', 'histogram_tendency']
# feature_target: ['fetal_health']

# %%
#TEMPLATE - verifying its a stratified split
def outcome_cat_proportions(data):
  return data.value_counts() / len(data)

compare_props = pd.DataFrame({
    "Overall": outcome_cat_proportions(health_data["fetal_health"]),
    "Train data": outcome_cat_proportions(y_train),
    "Test data": outcome_cat_proportions(y_test)
})
compare_props
# Out:
#       Overall  Train data  Test data
# 1.0  0.778457    0.778226   0.778997
# 2.0  0.138758    0.139113   0.137931
# 3.0  0.082785    0.082661   0.083072

# %% [markdown]
# # Train Data cleaning

# %%
#scale the inputs
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train =  pd.DataFrame(sc_X.fit_transform(X_train_raw),columns=feature_names)

# %%
X_train.describe().T
# Out:
#                                                          count          mean  \
# baseline value                                          1488.0 -1.293470e-15
# accelerations                                           1488.0 -8.761753e-17
# fetal_movement                                          1488.0 -8.994448e-17
# uterine_contractions                                    1488.0 -1.211695e-16
# light_decelerations                                     1488.0  2.644241e-16
# severe_decelerations                                    1488.0 -1.302908e-17
# prolongued_decelerations                                1488.0 -6.935163e-16
# abnormal_short_term_variability                         1488.0 -1.509023e-16
# mean_value_of_short_term_variability                    1488.0 -2.013025e-16
# percentage_of_time_with_abnormal_long_term_variability  1488.0  7.173921e-17
# mean_value_of_long_term_variability                     1488.0  2.589028e-16
# histogram_width                                         1488.0 -7.916308e-17
# histogram_min                                           1488.0  4.476706e-17
# histogram_max                                           1488.0 -6.759826e-17
# histogram_number_of_peaks                               1488.0 -4.812459e-17
# histogram_number_of_zeroes                              1488.0  6.168154e-16
# histogram_mode                                          1488.0 -4.019336e-16
# histogram_mean                                          1488.0  6.288652e-16
# histogram_median                                        1488.0 -7.636514e-16
# histogram_variance                                      1488.0 -1.175881e-16
# histogram_tendency                                      1488.0  7.849157e-17
#
#                                                              std       min  \
# baseline value                                          1.000336 -2.772164
# accelerations                                           1.000336 -0.828588
# fetal_movement                                          1.000336 -0.208281
# uterine_contractions                                    1.000336 -1.491886
# light_decelerations                                     1.000336 -0.628120
# severe_decelerations                                    1.000336 -0.051917
# prolongued_decelerations                                1.000336 -0.272159
# abnormal_short_term_variability                         1.000336 -2.021587
# mean_value_of_short_term_variability                    1.000336 -1.279636
# percentage_of_time_with_abnormal_long_term_variability  1.000336 -0.532022
# mean_value_of_long_term_variability                     1.000336 -1.470605
# histogram_width                                         1.000336 -1.731283
# histogram_min                                           1.000336 -1.476051
# histogram_max                                           1.000336 -2.327254
# histogram_number_of_peaks                               1.000336 -1.385148
# histogram_number_of_zeroes                              1.000336 -0.470174
# histogram_mode                                          1.000336 -4.692406
# histogram_mean                                          1.000336 -3.947914
# histogram_median                                        1.000336 -4.249202
# histogram_variance                                      1.000336 -0.637293
# histogram_tendency                                      1.000336 -2.161390
#
#                                                              25%       50%  \
# baseline value                                         -0.722484 -0.005097
# accelerations                                          -0.828588 -0.313468
# fetal_movement                                         -0.208281 -0.208281
# uterine_contractions                                   -0.806194 -0.120503
# light_decelerations                                    -0.628120 -0.628120
# severe_decelerations                                   -0.051917 -0.051917
# prolongued_decelerations                               -0.272159 -0.272159
# abnormal_short_term_variability                        -0.861919  0.065816
# mean_value_of_short_term_variability                   -0.717856 -0.156075
# percentage_of_time_with_abnormal_long_term_variability -0.532022 -0.532022
# mean_value_of_long_term_variability                    -0.658963 -0.135904
# histogram_width                                        -0.858995 -0.089329
# histogram_min                                          -0.898186  0.019600
# histogram_max                                          -0.661171 -0.161346
# histogram_number_of_peaks                              -0.704018 -0.363453
# histogram_number_of_zeroes                             -0.470174 -0.470174
# histogram_mode                                         -0.564818  0.072530
# histogram_mean                                         -0.608709  0.097661
# histogram_median                                       -0.695886  0.070516
# histogram_variance                                     -0.570535 -0.403641
# histogram_tendency                                     -0.527168 -0.527168
#
#                                                              75%        max
# baseline value                                          0.712291   2.761970
# accelerations                                           0.716771   3.807490
# fetal_movement                                         -0.147615   9.437601
# uterine_contractions                                    0.565189   3.307954
# light_decelerations                                     0.400844   4.516703
# severe_decelerations                                   -0.051917  19.261360
# prolongued_decelerations                               -0.272159   8.235661
# abnormal_short_term_variability                         0.819600   2.269185
# mean_value_of_short_term_variability                    0.405705   6.360579
# percentage_of_time_with_abnormal_long_term_variability  0.063121   4.391439
# mean_value_of_long_term_variability                     0.477337   5.888288
# histogram_width                                         0.782959   2.707124
# histogram_min                                           0.903394   2.195093
# histogram_max                                           0.560624   4.114935
# histogram_number_of_peaks                               0.658243   4.745026
# histogram_number_of_zeroes                             -0.470174  11.438233
# histogram_mode                                          0.649178   3.016471
# histogram_mean                                          0.675600   3.051573
# histogram_median                                        0.697572   3.345141
# histogram_variance                                      0.130420   7.840919
# histogram_tendency                                      1.107053   1.107053

# %% [markdown]
# #Test Data Cleaning

# %%
#scale the inputs
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_test =  pd.DataFrame(sc_X.fit_transform(X_test_raw),columns=feature_names)

# %%
X_test.describe().T
# Out:
#                                                         count          mean  \
# baseline value                                          638.0 -4.966421e-16
# accelerations                                           638.0 -1.301641e-16
# fetal_movement                                          638.0 -1.696657e-18
# uterine_contractions                                    638.0  2.683329e-16
# light_decelerations                                     638.0 -1.023215e-16
# severe_decelerations                                    638.0 -9.453427e-17
# prolongued_decelerations                                638.0 -8.944430e-17
# abnormal_short_term_variability                         638.0 -1.364287e-16
# mean_value_of_short_term_variability                    638.0 -1.632271e-16
# percentage_of_time_with_abnormal_long_term_variability  638.0  1.134585e-16
# mean_value_of_long_term_variability                     638.0 -8.491988e-17
# histogram_width                                         638.0  8.213562e-17
# histogram_min                                           638.0 -1.548744e-16
# histogram_max                                           638.0 -1.367767e-16
# histogram_number_of_peaks                               638.0  1.030176e-16
# histogram_number_of_zeroes                              638.0 -2.088194e-18
# histogram_mode                                          638.0  2.732054e-16
# histogram_mean                                          638.0 -4.642751e-16
# histogram_median                                        638.0 -1.663594e-16
# histogram_variance                                      638.0  3.671741e-17
# histogram_tendency                                      638.0  7.795923e-17
#
#                                                              std       min  \
# baseline value                                          1.000785 -2.789761
# accelerations                                           1.000785 -0.808095
# fetal_movement                                          1.000785 -0.192622
# uterine_contractions                                    1.000785 -1.461839
# light_decelerations                                     1.000785 -0.662811
# severe_decelerations                                    1.000785 -0.068734
# prolongued_decelerations                                1.000785 -0.260927
# abnormal_short_term_variability                         1.000785 -2.010655
# mean_value_of_short_term_variability                    1.000785 -1.291066
# percentage_of_time_with_abnormal_long_term_variability  1.000785 -0.543331
# mean_value_of_long_term_variability                     1.000785 -1.421891
# histogram_width                                         1.000785 -1.604251
# histogram_min                                           1.000785 -1.471567
# histogram_max                                           1.000785 -2.379245
# histogram_number_of_peaks                               1.000785 -1.367142
# histogram_number_of_zeroes                              1.000785 -0.438434
# histogram_mode                                          1.000785 -4.818929
# histogram_mean                                          1.000785 -3.578444
# histogram_median                                        1.000785 -4.099930
# histogram_variance                                      1.000785 -0.684399
# histogram_tendency                                      1.000785 -2.163687
#
#                                                              25%       50%  \
# baseline value                                         -0.689681 -0.089659
# accelerations                                          -0.808095 -0.546387
# fetal_movement                                         -0.192622 -0.192622
# uterine_contractions                                   -0.797556 -0.133273
# light_decelerations                                    -0.662811 -0.662811
# severe_decelerations                                   -0.068734 -0.068734
# prolongued_decelerations                               -0.260927 -0.260927
# abnormal_short_term_variability                        -0.896301  0.159404
# mean_value_of_short_term_variability                   -0.713922 -0.194492
# percentage_of_time_with_abnormal_long_term_variability -0.543331 -0.543331
# mean_value_of_long_term_variability                    -0.630733 -0.149158
# histogram_width                                        -0.858232 -0.060764
# histogram_min                                          -0.902277 -0.031598
# histogram_max                                          -0.692062 -0.073429
# histogram_number_of_peaks                              -0.695416 -0.191621
# histogram_number_of_zeroes                             -0.438434 -0.438434
# histogram_mode                                         -0.544779  0.136607
# histogram_mean                                         -0.634641  0.101310
# histogram_median                                       -0.566044  0.113550
# histogram_variance                                     -0.608959 -0.382639
# histogram_tendency                                     -0.518356 -0.518356
#
#                                                              75%        max
# baseline value                                          0.685371   2.510440
# accelerations                                           0.500445   4.164356
# fetal_movement                                         -0.141735  12.045795
# uterine_contractions                                    0.863152   3.520284
# light_decelerations                                     0.646394   3.919406
# severe_decelerations                                   -0.068734  14.548769
# prolongued_decelerations                               -0.260927   6.465188
# abnormal_short_term_variability                         0.804556   2.329462
# mean_value_of_short_term_variability                    0.440366   6.442666
# percentage_of_time_with_abnormal_long_term_variability  0.102985   4.187147
# mean_value_of_long_term_variability                     0.435612   7.298053
# histogram_width                                         0.736705   2.820412
# histogram_min                                           0.872569   2.178587
# histogram_max                                           0.601444   4.144528
# histogram_number_of_peaks                               0.648037   4.006668
# histogram_number_of_zeroes                             -0.438434  12.392797
# histogram_mode                                          0.632161   2.614375
# histogram_mean                                          0.709269   2.437153
# histogram_median                                        0.657224   2.628046
# histogram_variance                                      0.258601   9.462274
# histogram_tendency                                      1.126974   1.126974

# %% [markdown]
# # Decision Tree - Unconstrained Run
# Plain Decision tree execution

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

tree_clf = DecisionTreeClassifier(random_state=42)
tree_clf.fit(X_train,y_train)
np.mean(cross_val_score(tree_clf, X_train,y_train, cv=5))
# Out:
# 0.9186970374889839

# %%
# importance of features
print("tree_clf.feature_importances_", tree_clf.feature_importances_)
print("mean.feature_importances_", np.mean(tree_clf.feature_importances_))
sorted(zip(tree_clf.feature_importances_, feature_names), reverse=True)
# Out:
# tree_clf.feature_importances_ [0.02793196 0.04652902 0.01028038 0.04230746 0.00511511 0.
#  0.0239702  0.11301851 0.28171107 0.12357513 0.01426784 0.01702285
#  0.00820923 0.01884549 0.01660564 0.00182865 0.01980015 0.2061469
#  0.00622613 0.01268973 0.00391854]
# mean.feature_importances_ 0.04761904761904761
# [(0.28171107324579997, 'mean_value_of_short_term_variability'),
#  (0.20614689956055804, 'histogram_mean'),
#  (0.12357513108942304,
#   'percentage_of_time_with_abnormal_long_term_variability'),
#  (0.1130185062082352, 'abnormal_short_term_variability'),
#  (0.04652901985576612, 'accelerations'),
#  (0.04230746299053474, 'uterine_contractions'),
#  (0.027931959970674852, 'baseline value'),
#  (0.023970200517924343, 'prolongued_decelerations'),
#  (0.019800147998029344, 'histogram_mode'),
#  (0.018845491982177397, 'histogram_max'),
#  (0.017022854165142483, 'histogram_width'),
#  (0.016605640832334723, 'histogram_number_of_peaks'),
#  (0.014267842088427697, 'mean_value_of_long_term_variability'),
#  (0.012689725169070016, 'histogram_variance'),
#  (0.010280384276851235, 'fetal_movement'),
#  (0.00820922983266635, 'histogram_min'),
#  (0.006226125781645288, 'histogram_median'),
#  (0.00511511140552794, 'light_decelerations'),
#  (0.003918540701734797, 'histogram_tendency'),
#  (0.0018286523274762382, 'histogram_number_of_zeroes'),
#  (0.0, 'severe_decelerations')]

# %%
from graphviz import Source
from sklearn.tree import export_graphviz

export_graphviz(
        tree_clf,
        out_file=os.path.join("./", "fetal_health_dt.dot"),
        feature_names=feature_names,
        class_names=['1 (Normal)', '2 (Suspect)', '3 (Pathological)'],
        rounded=True,
        filled=True
        )

Source.from_file(os.path.join(".", "fetal_health_dt.dot"))

# %%
#TEMPLATE - Converet png file
import pydot

(graph,) = pydot.graph_from_dot_file('fetal_health_dt.dot')
graph.write_png('fetal_health_dt.png')

# %% [markdown]
# # Random search
# Random search to find hyper parameters which may possibly work for further fine tuning

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'max_depth': randint(low=1, high=30),
        'max_leaf_nodes': randint(low=1, high=100),
        'min_samples_leaf': randint(low=1, high=100),
    }

tree_clf_unconst = DecisionTreeClassifier(random_state=42)
rnd_search = RandomizedSearchCV(tree_clf_unconst, param_distributions=param_distribs,
                                n_iter=100, cv=5, scoring='f1_weighted', random_state=42)
rnd_search.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py", line 942, in fit
#     X_idx_sorted=X_idx_sorted,
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py", line 316, in fit
#     max_leaf_nodes
# ValueError: max_leaf_nodes 1 must be either None or larger than 1
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:972: UserWarning: One or more of the test scores are non-finite: [0.8422104  0.85630042 0.83731779 0.83731779 0.93061787 0.92442131
#  0.89833732 0.85691911 0.84637077 0.83731779 0.85692022 0.85692022
#  0.85477061 0.86672238 0.85292522 0.8722393  0.84427904 0.92099868
#  0.90469001 0.84023581 0.79889996 0.84868601 0.87367053 0.84664593
#  0.91060257 0.86296077 0.86296077 0.90403776 0.89563716 0.90469001
#  0.84397883 0.85477061 0.84664593 0.85502227 0.83731779 0.88950517
#  0.87507869 0.79889996 0.92261078 0.83731779 0.92336135 0.90120338
#  0.88950517 0.84427904 0.89563716 0.79889996 0.85395343 0.84023581
#  0.85395343 0.84664593        nan 0.90810398 0.9100264  0.84664593
#  0.85395343 0.85395343 0.91093466 0.8824345  0.90514705 0.84053501
#  0.89024651 0.86036325 0.90509593 0.84053501 0.83731779 0.85395343
#  0.79889996 0.92449084 0.84397883 0.85477061 0.86672238 0.90997529
#  0.89947633 0.85477061 0.85502227 0.92949231 0.84664593 0.79889996
#  0.83731779 0.85395343 0.79889996 0.84023581 0.8493042  0.86042478
#  0.89833732 0.85395343 0.91091033 0.85395343 0.84868601 0.92449084
#  0.89365552 0.8493042  0.85395343 0.8979719  0.84271172        nan
#  0.83731779 0.90153207 0.92549728 0.84023581]
#   category=UserWarning,
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#                    n_iter=100,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f5a3f1302d0>,
#                                         'max_leaf_nodes': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f5a41957910>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f5a3f2c89d0>},
#                    random_state=42, scoring='f1_weighted')

# %%
rnd_search_df = pd.DataFrame({'param': rnd_search.cv_results_["params"], 'f1_weighted': rnd_search.cv_results_["mean_test_score"]})
rnd_search_df.sort_values(by=['f1_weighted'], ascending=False)
# Out:
#                                                               param  f1_weighted
# 4    {'max_depth': 21, 'max_leaf_nodes': 24, 'min_samples_leaf': 3}     0.930618
# 75   {'max_depth': 12, 'max_leaf_nodes': 39, 'min_samples_leaf': 2}     0.929492
# 98   {'max_depth': 10, 'max_leaf_nodes': 99, 'min_samples_leaf': 7}     0.925497
# 89   {'max_depth': 16, 'max_leaf_nodes': 93, 'min_samples_leaf': 3}     0.924491
# 67   {'max_depth': 25, 'max_leaf_nodes': 77, 'min_samples_leaf': 3}     0.924491
# 5    {'max_depth': 22, 'max_leaf_nodes': 53, 'min_samples_leaf': 2}     0.924421
# 40   {'max_depth': 11, 'max_leaf_nodes': 81, 'min_samples_leaf': 8}     0.923361
# 38    {'max_depth': 9, 'max_leaf_nodes': 88, 'min_samples_leaf': 1}     0.922611
# 17    {'max_depth': 7, 'max_leaf_nodes': 18, 'min_samples_leaf': 4}     0.920999
# 56   {'max_depth': 4, 'max_leaf_nodes': 94, 'min_samples_leaf': 23}     0.910935
# 86   {'max_depth': 6, 'max_leaf_nodes': 86, 'min_samples_leaf': 11}     0.910910
# 24    {'max_depth': 4, 'max_leaf_nodes': 50, 'min_samples_leaf': 4}     0.910603
# 52   {'max_depth': 9, 'max_leaf_nodes': 79, 'min_samples_leaf': 15}     0.910026
# 71  {'max_depth': 10, 'max_leaf_nodes': 44, 'min_samples_leaf': 24}     0.909975
# 51  {'max_depth': 26, 'max_leaf_nodes': 14, 'min_samples_leaf': 27}     0.908104
# 58  {'max_depth': 29, 'max_leaf_nodes': 36, 'min_samples_leaf': 13}     0.905147
# 62   {'max_depth': 21, 'max_leaf_nodes': 6, 'min_samples_leaf': 28}     0.905096
# 18  {'max_depth': 25, 'max_leaf_nodes': 60, 'min_samples_leaf': 14}     0.904690
# 29  {'max_depth': 10, 'max_leaf_nodes': 62, 'min_samples_leaf': 14}     0.904690
# 27  {'max_depth': 29, 'max_leaf_nodes': 63, 'min_samples_leaf': 18}     0.904038
# 97  {'max_depth': 18, 'max_leaf_nodes': 23, 'min_samples_leaf': 31}     0.901532
# 41   {'max_depth': 3, 'max_leaf_nodes': 35, 'min_samples_leaf': 33}     0.901203
# 72  {'max_depth': 15, 'max_leaf_nodes': 59, 'min_samples_leaf': 32}     0.899476
# 6   {'max_depth': 24, 'max_leaf_nodes': 30, 'min_samples_leaf': 38}     0.898337
# 84  {'max_depth': 27, 'max_leaf_nodes': 17, 'min_samples_leaf': 38}     0.898337
# 93   {'max_depth': 7, 'max_leaf_nodes': 52, 'min_samples_leaf': 33}     0.897972
# 28  {'max_depth': 26, 'max_leaf_nodes': 44, 'min_samples_leaf': 34}     0.895637
# 44   {'max_depth': 8, 'max_leaf_nodes': 12, 'min_samples_leaf': 34}     0.895637
# 90  {'max_depth': 20, 'max_leaf_nodes': 59, 'min_samples_leaf': 36}     0.893656
# 60  {'max_depth': 28, 'max_leaf_nodes': 66, 'min_samples_leaf': 42}     0.890247
# 42   {'max_depth': 27, 'max_leaf_nodes': 5, 'min_samples_leaf': 41}     0.889505
# 35  {'max_depth': 28, 'max_leaf_nodes': 60, 'min_samples_leaf': 41}     0.889505
# 57   {'max_depth': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 43}     0.882435
# 36  {'max_depth': 29, 'max_leaf_nodes': 15, 'min_samples_leaf': 45}     0.875079
# 22   {'max_depth': 12, 'max_leaf_nodes': 8, 'min_samples_leaf': 47}     0.873671
# 15   {'max_depth': 25, 'max_leaf_nodes': 3, 'min_samples_leaf': 51}     0.872239
# 70   {'max_depth': 5, 'max_leaf_nodes': 97, 'min_samples_leaf': 51}     0.866722
# 13  {'max_depth': 15, 'max_leaf_nodes': 62, 'min_samples_leaf': 51}     0.866722
# 25    {'max_depth': 2, 'max_leaf_nodes': 6, 'min_samples_leaf': 54}     0.862961
# 26   {'max_depth': 10, 'max_leaf_nodes': 4, 'min_samples_leaf': 54}     0.862961
# 83  {'max_depth': 23, 'max_leaf_nodes': 75, 'min_samples_leaf': 56}     0.860425
# 61  {'max_depth': 13, 'max_leaf_nodes': 62, 'min_samples_leaf': 57}     0.860363
# 11  {'max_depth': 10, 'max_leaf_nodes': 92, 'min_samples_leaf': 60}     0.856920
# 10  {'max_depth': 17, 'max_leaf_nodes': 91, 'min_samples_leaf': 59}     0.856920
# 7    {'max_depth': 2, 'max_leaf_nodes': 64, 'min_samples_leaf': 60}     0.856919
# 1   {'max_depth': 15, 'max_leaf_nodes': 72, 'min_samples_leaf': 61}     0.856300
# 74  {'max_depth': 17, 'max_leaf_nodes': 58, 'min_samples_leaf': 52}     0.855022
# 33  {'max_depth': 13, 'max_leaf_nodes': 82, 'min_samples_leaf': 53}     0.855022
# 73  {'max_depth': 24, 'max_leaf_nodes': 52, 'min_samples_leaf': 62}     0.854771
# 12  {'max_depth': 16, 'max_leaf_nodes': 15, 'min_samples_leaf': 62}     0.854771
# 69   {'max_depth': 27, 'max_leaf_nodes': 9, 'min_samples_leaf': 62}     0.854771
# 31  {'max_depth': 14, 'max_leaf_nodes': 87, 'min_samples_leaf': 62}     0.854771
# 48   {'max_depth': 3, 'max_leaf_nodes': 65, 'min_samples_leaf': 99}     0.853953
# 87  {'max_depth': 16, 'max_leaf_nodes': 16, 'min_samples_leaf': 97}     0.853953
# 46  {'max_depth': 24, 'max_leaf_nodes': 37, 'min_samples_leaf': 99}     0.853953
# 54  {'max_depth': 19, 'max_leaf_nodes': 63, 'min_samples_leaf': 96}     0.853953
# 55   {'max_depth': 7, 'max_leaf_nodes': 52, 'min_samples_leaf': 96}     0.853953
# 65   {'max_depth': 7, 'max_leaf_nodes': 62, 'min_samples_leaf': 97}     0.853953
# 79   {'max_depth': 5, 'max_leaf_nodes': 96, 'min_samples_leaf': 97}     0.853953
# 85  {'max_depth': 24, 'max_leaf_nodes': 69, 'min_samples_leaf': 98}     0.853953
# 92  {'max_depth': 19, 'max_leaf_nodes': 20, 'min_samples_leaf': 96}     0.853953
# 14  {'max_depth': 12, 'max_leaf_nodes': 55, 'min_samples_leaf': 64}     0.852925
# 82   {'max_depth': 6, 'max_leaf_nodes': 32, 'min_samples_leaf': 68}     0.849304
# 91  {'max_depth': 19, 'max_leaf_nodes': 90, 'min_samples_leaf': 67}     0.849304
# 88   {'max_depth': 9, 'max_leaf_nodes': 59, 'min_samples_leaf': 70}     0.848686
# 21  {'max_depth': 28, 'max_leaf_nodes': 60, 'min_samples_leaf': 71}     0.848686
# 53  {'max_depth': 26, 'max_leaf_nodes': 42, 'min_samples_leaf': 77}     0.846646
# 32   {'max_depth': 8, 'max_leaf_nodes': 85, 'min_samples_leaf': 80}     0.846646
# 23   {'max_depth': 3, 'max_leaf_nodes': 78, 'min_samples_leaf': 81}     0.846646
# 76   {'max_depth': 3, 'max_leaf_nodes': 56, 'min_samples_leaf': 81}     0.846646
# 49   {'max_depth': 5, 'max_leaf_nodes': 47, 'min_samples_leaf': 78}     0.846646
# 8   {'max_depth': 21, 'max_leaf_nodes': 33, 'min_samples_leaf': 76}     0.846371
# 43   {'max_depth': 28, 'max_leaf_nodes': 7, 'min_samples_leaf': 73}     0.844279
# 16   {'max_depth': 7, 'max_leaf_nodes': 21, 'min_samples_leaf': 73}     0.844279
# 68   {'max_depth': 7, 'max_leaf_nodes': 70, 'min_samples_leaf': 72}     0.843979
# 30  {'max_depth': 16, 'max_leaf_nodes': 15, 'min_samples_leaf': 72}     0.843979
# 94   {'max_depth': 8, 'max_leaf_nodes': 39, 'min_samples_leaf': 82}     0.842712
# 0    {'max_depth': 7, 'max_leaf_nodes': 52, 'min_samples_leaf': 93}     0.842210
# 63  {'max_depth': 28, 'max_leaf_nodes': 44, 'min_samples_leaf': 84}     0.840535
# 59   {'max_depth': 7, 'max_leaf_nodes': 59, 'min_samples_leaf': 86}     0.840535
# 99  {'max_depth': 28, 'max_leaf_nodes': 16, 'min_samples_leaf': 90}     0.840236
# 81  {'max_depth': 21, 'max_leaf_nodes': 44, 'min_samples_leaf': 90}     0.840236
# 47  {'max_depth': 12, 'max_leaf_nodes': 86, 'min_samples_leaf': 91}     0.840236
# 19   {'max_depth': 18, 'max_leaf_nodes': 9, 'min_samples_leaf': 90}     0.840236
# 34  {'max_depth': 24, 'max_leaf_nodes': 26, 'min_samples_leaf': 89}     0.837318
# 2   {'max_depth': 21, 'max_leaf_nodes': 83, 'min_samples_leaf': 87}     0.837318
# 3   {'max_depth': 11, 'max_leaf_nodes': 75, 'min_samples_leaf': 88}     0.837318
# 96  {'max_depth': 28, 'max_leaf_nodes': 57, 'min_samples_leaf': 89}     0.837318
# 9   {'max_depth': 26, 'max_leaf_nodes': 22, 'min_samples_leaf': 89}     0.837318
# 78  {'max_depth': 28, 'max_leaf_nodes': 54, 'min_samples_leaf': 87}     0.837318
# 64  {'max_depth': 11, 'max_leaf_nodes': 92, 'min_samples_leaf': 89}     0.837318
# 39   {'max_depth': 12, 'max_leaf_nodes': 8, 'min_samples_leaf': 88}     0.837318
# 37   {'max_depth': 1, 'max_leaf_nodes': 89, 'min_samples_leaf': 71}     0.798900
# 20   {'max_depth': 21, 'max_leaf_nodes': 2, 'min_samples_leaf': 84}     0.798900
# 80    {'max_depth': 1, 'max_leaf_nodes': 19, 'min_samples_leaf': 2}     0.798900
# 45   {'max_depth': 1, 'max_leaf_nodes': 48, 'min_samples_leaf': 23}     0.798900
# 66   {'max_depth': 1, 'max_leaf_nodes': 27, 'min_samples_leaf': 62}     0.798900
# 77    {'max_depth': 27, 'max_leaf_nodes': 2, 'min_samples_leaf': 2}     0.798900
# 50     {'max_depth': 3, 'max_leaf_nodes': 1, 'min_samples_leaf': 5}          NaN
# 95    {'max_depth': 8, 'max_leaf_nodes': 1, 'min_samples_leaf': 11}          NaN

# %%
rnd_search.best_estimator_
# DecisionTreeClassifier(max_depth=21, max_leaf_nodes=24, min_samples_leaf=3,random_state=42)
# Out:
# DecisionTreeClassifier(max_depth=21, max_leaf_nodes=24, min_samples_leaf=3,
#                        random_state=42)

# %% [markdown]
# # Grid search
# Grid search to find best parameters

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try combinations of depth starting at 2
    {'max_depth': list(range(19, 23)), 'max_leaf_nodes': list(range(20,28))},
    # {'max_depth': list(range(24, 28)), 'max_leaf_nodes': list(range(12,17)), 'min_samples_leaf': list(range(24,28))},
    # {'max_features':list(range(1,21))},
  ]

tree_clf_unconst = DecisionTreeClassifier(random_state=42)
# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(tree_clf_unconst, param_grid, cv=5,
                           scoring='f1_weighted',
                           return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid=[{'max_depth': [19, 20, 21, 22],
#                           'max_leaf_nodes': [20, 21, 22, 23, 24, 25, 26, 27]}],
#              return_train_score=True, scoring='f1_weighted')

# %%
grid_search_df = pd.DataFrame({'param': grid_search.cv_results_["params"], 'f1_weighted': grid_search.cv_results_["mean_test_score"]})
grid_search_df.sort_values(by=['f1_weighted'], ascending=False)
# {'max_features': 9}	0.919762
# {'max_features': 12}	0.924491
# {'max_depth': 20, 'max_leaf_nodes': 24}	0.930642
# Out:
#                                       param  f1_weighted
# 12  {'max_depth': 20, 'max_leaf_nodes': 24}     0.930642
# 4   {'max_depth': 19, 'max_leaf_nodes': 24}     0.930642
# 20  {'max_depth': 21, 'max_leaf_nodes': 24}     0.930642
# 28  {'max_depth': 22, 'max_leaf_nodes': 24}     0.930642
# 14  {'max_depth': 20, 'max_leaf_nodes': 26}     0.930569
# 22  {'max_depth': 21, 'max_leaf_nodes': 26}     0.930569
# 6   {'max_depth': 19, 'max_leaf_nodes': 26}     0.930569
# 30  {'max_depth': 22, 'max_leaf_nodes': 26}     0.930569
# 23  {'max_depth': 21, 'max_leaf_nodes': 27}     0.930416
# 15  {'max_depth': 20, 'max_leaf_nodes': 27}     0.930416
# 31  {'max_depth': 22, 'max_leaf_nodes': 27}     0.930416
# 7   {'max_depth': 19, 'max_leaf_nodes': 27}     0.930416
# 5   {'max_depth': 19, 'max_leaf_nodes': 25}     0.929831
# 13  {'max_depth': 20, 'max_leaf_nodes': 25}     0.929831
# 29  {'max_depth': 22, 'max_leaf_nodes': 25}     0.929831
# 21  {'max_depth': 21, 'max_leaf_nodes': 25}     0.929831
# 11  {'max_depth': 20, 'max_leaf_nodes': 23}     0.927817
# 3   {'max_depth': 19, 'max_leaf_nodes': 23}     0.927817
# 19  {'max_depth': 21, 'max_leaf_nodes': 23}     0.927817
# 27  {'max_depth': 22, 'max_leaf_nodes': 23}     0.927817
# 17  {'max_depth': 21, 'max_leaf_nodes': 21}     0.926483
# 1   {'max_depth': 19, 'max_leaf_nodes': 21}     0.926483
# 9   {'max_depth': 20, 'max_leaf_nodes': 21}     0.926483
# 25  {'max_depth': 22, 'max_leaf_nodes': 21}     0.926483
# 10  {'max_depth': 20, 'max_leaf_nodes': 22}     0.925825
# 18  {'max_depth': 21, 'max_leaf_nodes': 22}     0.925825
# 2   {'max_depth': 19, 'max_leaf_nodes': 22}     0.925825
# 26  {'max_depth': 22, 'max_leaf_nodes': 22}     0.925825
# 0   {'max_depth': 19, 'max_leaf_nodes': 20}     0.925733
# 24  {'max_depth': 22, 'max_leaf_nodes': 20}     0.925733
# 8   {'max_depth': 20, 'max_leaf_nodes': 20}     0.925733
# 16  {'max_depth': 21, 'max_leaf_nodes': 20}     0.925733

# %%
#Based on grid search define best estimator for generating learning curves, confusion matrix & for final predict()
best_estimator = DecisionTreeClassifier(random_state=42,max_depth=20, max_leaf_nodes=24)
best_est_title = 'max_depth=20,max_leaf_nodes=24'
#min_samples_leaf=27

# %% [markdown]
# # Learning Curve
# Based on grid search define best estimator for generating learning curves, confusion matrix & for final predict()

# %%
from sklearn.model_selection import learning_curve

def learning_curves(estimator, data, features, y, cv,title):
   plt.figure(figsize = (16,5))
   tot_col = 2
  #call learning curve function
   train_sizes, train_scores, validation_scores,fit_times, _ = learning_curve(estimator, data[features], y, cv = cv, scoring = 'f1_weighted', shuffle=True,return_times=True)
   #find the mean values
   train_scores_mean = train_scores.mean(axis = 1)
   validation_scores_mean = validation_scores.mean(axis = 1)
   fit_times_mean = fit_times.mean(axis = 1)
   #Plot-1 - Learning Curve: training error and validation error   
   plt.subplot(1,tot_col,(1))
   plt.plot(train_sizes, train_scores_mean, "o-", label = 'Training score')
   plt.plot(train_sizes, validation_scores_mean, "o-", label = 'Validation score')
   plt.ylabel('f1 weighted', fontsize = 14)
   plt.xlabel('Training set size', fontsize = 14)
  #  title = 'Learning curves for ' +  title
   plt.title(title, fontsize = 18, y = 1.03)
   plt.legend()
   plt.ylim(0,1.10)

   #Plot-2 - Scalability of the model - Plot n_samples vs fit_times
   plt.subplot(1,tot_col,(2))
   plt.plot(train_sizes, fit_times_mean, "o-", label = 'Training fit-times')
   plt.ylabel('fit_times', fontsize = 14)
   plt.xlabel('Training set size', fontsize = 14)
   plt.title("Scalability of the model", fontsize = 18, y = 1.03)
   plt.legend()
  #  plt.ylim(*ylim)

  #  #Plot-3 - Performance of the model - Plot fit_time vs score
  #  fit_time_argsort = fit_times_mean.argsort()
  #  fit_time_sorted = fit_times_mean[fit_time_argsort]
  #  validation_scores_mean_sorted = validation_scores_mean[fit_time_argsort]
  # #  test_scores_std_sorted = test_scores_std[fit_time_argsort]
  #  plt.subplot(1,tot_col,(3))
  #  plt.plot(fit_time_sorted, validation_scores_mean_sorted)
  #  plt.ylabel('fit_times', fontsize = 14)
  #  plt.xlabel('Score', fontsize = 14)
  #  plt.title("Performance of the model", fontsize = 18, y = 1.03)
  #  plt.legend()
  #  plt.ylim(*ylim)

# %%
#run learning_curves
learning_curves(best_estimator, X_train, feature_names, y_train, 5,best_est_title)
plt.savefig('learning_curves.pdf')

# %% [markdown]
# # Confusion Matrix, Precisioin & Recall

# %%
#import confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_predict
from sklearn import metrics

y_train_pred = cross_val_predict(best_estimator,X_train,y_train, cv=5)
cnf_matrix = metrics.confusion_matrix(y_train, y_train_pred)
p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.savefig('confusion_matrix.pdf')

# %%
from sklearn.metrics import f1_score
f1_score(y_train,y_train_pred,average='weighted')
# Out:
# 0.9308665224135938

# %%
from sklearn.metrics import precision_score, recall_score
precision_score(y_train,y_train_pred,average='weighted')
# Out:
# 0.9304355009715446

# %%
recall_score(y_train,y_train_pred,average='weighted')
# Out:
# 0.9321236559139785

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.95      0.97      0.96      1158
#          2.0       0.83      0.74      0.78       207
#          3.0       0.91      0.94      0.92       123
#
#     accuracy                           0.93      1488
#    macro avg       0.89      0.88      0.89      1488
# weighted avg       0.93      0.93      0.93      1488

# %% [markdown]
# # Validation Curve
# generate validation curve to develop intuition for analysis

# %%
from sklearn.model_selection import validation_curve

def validation_curves(estimator, data, features, y,param_name, param_range,invert_axis):
   #call valiidation curve function
   train_scores, validation_scores = validation_curve(estimator, data[features], y, param_name=param_name, param_range=param_range, cv = 5, scoring = 'f1_weighted')
   train_scores_mean = train_scores.mean(axis = 1)
   validation_scores_mean = validation_scores.mean(axis = 1)
   #Plot training error and validation error   
   plt.plot(param_range, train_scores_mean,label = 'Training score')
   plt.plot(param_range, validation_scores_mean, label = 'Validation score')
   # provide x & y labels
   plt.ylabel('f1_weighted', fontsize = 14)
   plt.xlabel(param_name, fontsize = 14)
   if invert_axis:
     ax = plt.gca()
     ax.invert_xaxis()
   title =  param_name
   plt.title(title, fontsize = 18, y = 1.03)
   plt.legend()
   plt.ylim(0.6,1.10)

# %%
#execute validation curves
plt.figure(figsize = (16,5))
tree_clf_unconst = DecisionTreeClassifier(random_state=42)

for model, param_name, param_range,i,invert_axis in [(tree_clf_unconst,"max_depth" , np.arange(1, 25, 2), 0,True), (tree_clf_unconst,"max_leaf_nodes", np.arange(1, 100, 5),1,True),(tree_clf_unconst,"min_samples_leaf", np.arange(1, 30, 3),2,False)]:
    plt.subplot(1,3,(i+1))
    validation_curves(model, X_train, feature_names, y_train, param_name, param_range,invert_axis=invert_axis)
plt.savefig('validation_curves.pdf')

# %% [markdown]
# #Test set prediction

# %%
#fit the best model
best_estimator.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=20, max_leaf_nodes=24, random_state=42)

# %%
#use the model to predict
y_test_pred = best_estimator.predict(X_test)

# %%
#calculate weighted f1 score weighted
from sklearn.metrics import f1_score
f1_score(y_test,y_test_pred,average='weighted')
# Out:
# 0.9007044431387505

# %%
precision_score(y_test,y_test_pred,average='weighted')
# Out:
# 0.9008340797133901

# %%
recall_score(y_test,y_test_pred,average='weighted')
# Out:
# 0.9059561128526645

# %% [markdown]
# #References
#
#
# *   Learning curves for ML: https://www.dataquest.io/blog/learning-curves-machine-learning/
# *   Scoring values for learning_curve: https://stackoverflow.com/questions/46863421/what-is-the-score-in-plot-learning-curve-of-scikit-learn
# * Measures of central tendancy: Mean, Median & Mode : https://statisticsbyjim.com/basics/measures-central-tendency-mean-median-mode/
# * validation curves: https://www.geeksforgeeks.org/validation-curve/
# * Applied machine learning: https://amueller.github.io/aml/00-introduction/00-introduction.html
